# %%
from osgeo import gdal

# %%
# !gdalinfo

# %%
gdal.UseExceptions()

# %%
ds = gdal.OpenEx("lubelskie.tif", gdal.OF_RASTER)

# %%
ds.RasterCount

# %%
band = ds.GetRasterBand(1)

# %%
band

# %%
data = band.ReadAsArray()

# %%
data

# %%
data.min()

# %%
data.max()

# %%
# !gdalinfo lubelskie.tif
